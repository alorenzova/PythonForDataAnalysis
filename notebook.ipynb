# %%
print("ekekeke")

print("mnau")
# Out:
# ekekeke
# mnau

# %%
1+1
# Out:
# 2

# %% [markdown]
# # mnau text
# * dvakrat kliknout - uprava
# * code v md - ulozi se jako text
# * shift+enter - ulozi se (nejde spustit pres "play")
# * knihovna pandas, polars (pro velka data)
# * v pandas - sloupec se nazyvaji series, dataframe je tabulka (dataframe = vice series vedle sebe)
# * cisla v tabulce - identifikace radku - index (neni ID!!!), zacina 0

# %%
import pandas

# %%
import pandas as pd

# %%
food = pd.read_csv("food_sample_100.csv")

# %%
food
# Out:
#      fdc_id           data_type  \
# 0   2644829     sub_sample_food
# 1   2347263     sub_sample_food
# 2   2261954     sub_sample_food
# 3    321470     sub_sample_food
# 4    322951     sub_sample_food
# ..      ...                 ...
# 95  2260615     sub_sample_food
# 96  2646468     sub_sample_food
# 97  2647032     sub_sample_food
# 98  2349564     sub_sample_food
# 99   328565  market_acquisition
#
#                                           description  food_category_id  \
# 0                                        lentils, dry              16.0
# 1                                         heavy cream               1.0
# 2                                       Flour, potato              11.0
# 3                                       Salt, Iodized               2.0
# 4                                       Hot dogs beef               7.0
# ..                                                ...               ...
# ...

# %%
print(food)
# Out:
#      fdc_id           data_type  \
# 0   2644829     sub_sample_food
# 1   2347263     sub_sample_food
# 2   2261954     sub_sample_food
# 3    321470     sub_sample_food
# 4    322951     sub_sample_food
# ..      ...                 ...
# 95  2260615     sub_sample_food
# 96  2646468     sub_sample_food
# 97  2647032     sub_sample_food
# 98  2349564     sub_sample_food
# 99   328565  market_acquisition
#
#                                           description  food_category_id  \
# 0                                        lentils, dry              16.0
# 1                                         heavy cream               1.0
# 2                                       Flour, potato              11.0
# 3                                       Salt, Iodized               2.0
# 4                                       Hot dogs beef               7.0
# ..                                                ...               ...
# ...

# %% [markdown]
# ## Notes
# * notebook - dela to, co je na poslednim radku bunky
# * set_index --> food.set_index("fdc_id") - jen na nahled, jinak musi byt =
# * kdyt si to rozmyslim --> food = food.reset_index()

# %%
food.set_index("fdc_id")
# Out:
#                   data_type  \
# fdc_id
# 2644829     sub_sample_food
# 2347263     sub_sample_food
# 2261954     sub_sample_food
# 321470      sub_sample_food
# 322951      sub_sample_food
# ...                     ...
# 2260615     sub_sample_food
# 2646468     sub_sample_food
# 2647032     sub_sample_food
# 2349564     sub_sample_food
# 328565   market_acquisition
#
#                                                description  food_category_id  \
# fdc_id
# 2644829                                       lentils, dry              16.0
# 2347263                                        heavy cream               1.0
# 2261954                                      Flour, potato              11.0
# 321470                                       Salt, Iodized               2.0
# 322951                                       Hot dogs beef               7.0
# ...                                                    ...               ...
# ...

# %%
food = food.set_index("fdc_id")

# %%
food = food.reset_index()
food
# Out:
#      fdc_id           data_type  \
# 0   2644829     sub_sample_food
# 1   2347263     sub_sample_food
# 2   2261954     sub_sample_food
# 3    321470     sub_sample_food
# 4    322951     sub_sample_food
# ..      ...                 ...
# 95  2260615     sub_sample_food
# 96  2646468     sub_sample_food
# 97  2647032     sub_sample_food
# 98  2349564     sub_sample_food
# 99   328565  market_acquisition
#
#                                           description  food_category_id  \
# 0                                        lentils, dry              16.0
# 1                                         heavy cream               1.0
# 2                                       Flour, potato              11.0
# 3                                       Salt, Iodized               2.0
# 4                                       Hot dogs beef               7.0
# ..                                                ...               ...
# ...

# %%
food.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   fdc_id            100 non-null    int64
#  1   data_type         100 non-null    object
#  2   description       100 non-null    object
#  3   food_category_id  99 non-null     float64
#  4   publication_date  100 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 4.0+ KB

# %%
food.head()
food.tail(2)
food.tail(70)
food.sample(10)
# Out:
#      fdc_id        data_type  \
# 70  2259010  sub_sample_food
# 11  2263313  sub_sample_food
# 91   323481  sub_sample_food
# 52  2514498  sub_sample_food
# 90   332126  sub_sample_food
# 0   2644829  sub_sample_food
# 54  2515797  sub_sample_food
# 55  2514344  sub_sample_food
# 68   323199  sub_sample_food
# 10  2004036  sub_sample_food
#
#                                           description  food_category_id  \
# 70                            peppers, bell, red, raw              11.0
# 11                              peanut butter, creamy              16.0
# 91                                               Kale              11.0
# 52                                         rye, flour              20.0
# 90  Minerals, Sauce, pasta, PREGO 100% Natural Ita...               6.0
# 0                                        lentils, dry              16.0
# 54                                      coconut flour              12.0
# ...

# %%
food.columns
# Out:
# Index(['fdc_id', 'data_type', 'description', 'food_category_id',
#        'publication_date'],
#       dtype='object')

# %%
food.shape
# Out:
# (100, 5)

# %% [markdown]
# * shape = pocet radku, pocet sloupecku
# * tab - odkliknout napovedu
# * jeden sloupec --> series

# %%
food["description"]
# Out:
# 0                                          lentils, dry
# 1                                           heavy cream
# 2                                         Flour, potato
# 3                                         Salt, Iodized
# 4                                         Hot dogs beef
#                             ...
# 95                            Yogurt, whole milk, plain
# 96                  chicken, breast, boneless, skinless
# 97                                 pork, loin, boneless
# 98             Oats, whole grain, rolled, old fashioned
# 99    Cheese, cheddar, mild, block/chunk, store bran...
# Name: description, Length: 100, dtype: object

# %%
["description", "fdc_id"]
food[["description", "fdc_id"]]
# Out:
#                                           description   fdc_id
# 0                                        lentils, dry  2644829
# 1                                         heavy cream  2347263
# 2                                       Flour, potato  2261954
# 3                                       Salt, Iodized   321470
# 4                                       Hot dogs beef   322951
# ..                                                ...      ...
# 95                          Yogurt, whole milk, plain  2260615
# 96                chicken, breast, boneless, skinless  2646468
# 97                               pork, loin, boneless  2647032
# 98           Oats, whole grain, rolled, old fashioned  2349564
# 99  Cheese, cheddar, mild, block/chunk, store bran...   328565
#
# [100 rows x 2 columns]

# %%
food[["description"]]
# Out:
#                                           description
# 0                                        lentils, dry
# 1                                         heavy cream
# 2                                       Flour, potato
# 3                                       Salt, Iodized
# 4                                       Hot dogs beef
# ..                                                ...
# 95                          Yogurt, whole milk, plain
# 96                chicken, breast, boneless, skinless
# 97                               pork, loin, boneless
# 98           Oats, whole grain, rolled, old fashioned
# 99  Cheese, cheddar, mild, block/chunk, store bran...
#
# [100 rows x 1 columns]

# %% [markdown]
# * [[column]] --> obejit jeden sloupecek / series
# * describe - popisna statistika z cisel (ciselne sloupecky dataframe)

# %%
food.describe()
# Out:
#              fdc_id  food_category_id
# count  1.000000e+02         99.000000
# mean   1.721896e+06         10.343434
# std    8.963228e+05          5.792609
# min    3.214700e+05          1.000000
# 25%    6.444032e+05          6.500000
# 50%    2.007080e+06         11.000000
# 75%    2.351180e+06         14.500000
# max    2.648500e+06         20.000000

# %%
food.describe(percentiles=[.1, .2, .45, .9], include="all")
# Out:
#               fdc_id        data_type             description  \
# count   1.000000e+02              100                     100
# unique           NaN                4                      83
# top              NaN  sub_sample_food  buckwheat, whole grain
# freq             NaN               84                       3
# mean    1.721896e+06              NaN                     NaN
# std     8.963228e+05              NaN                     NaN
# min     3.214700e+05              NaN                     NaN
# 10%     3.276880e+05              NaN                     NaN
# 20%     3.325340e+05              NaN                     NaN
# 45%     2.003938e+06              NaN                     NaN
# 50%     2.007080e+06              NaN                     NaN
# 90%     2.644584e+06              NaN                     NaN
# max     2.648500e+06              NaN                     NaN
#
#         food_category_id publication_date
# count          99.000000              100
# ...

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.columns
titanic.shape[0]
# Out:
# 891

# %%
titanic[["Name"]]
titanic[["PassengerId", "Pclass"]]
titanic.head()
titanic.tail(2)
titanic.tail(70)
titanic.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 231          232         0       3
# 777          778         1       3
# 767          768         0       3
# 536          537         0       1
# 310          311         1       1
# 556          557         1       1
# 217          218         0       2
# 494          495         0       3
# 158          159         0       3
# 487          488         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 231                           Larsson, Mr. Bengt Edvin    male  29.0      0
# 777                      Emanuel, Miss. Virginia Ethel  female   5.0      0
# 767                                 Mangan, Miss. Mary  female  30.5      0
# 536                  Butt, Major. Archibald Willingham    male  45.0      0
# 310                     Hays, Miss. Margaret Bechstein  female  24.0      0
# 556  Duff Gordon, Lady. (Lucille Christiana Sutherl...  female  48.0      1
# ...
